# %% [markdown]
# # python objective

# %% [markdown]
# 1	-	a
#
# 2	-	b
#
# 3	-	b
#
# 4	-	d
#
# 5	-	d
#
# 6	-	c
#
# 7	-	d
#
# 8	-	d
#
# 9	-	d
#
# 10	-	a
#
# 11	-	c
#
# 12	-	a
#
# 13	-	c
#
# 14	-	b
#
# 15	-	b
#
# 16	-	c
#
# 17	-	b
#
# 18	-	d
#
# 19	-	b
#
# 20	-	c
#
# 21	-	a
#
# 22	-	d
#
# 23	-	d
#
# 24	-	c
#
# 25	-	d
#
# 26	-	c
#
# 27	-	b
#
# 28	-	c
#
# 29	-	b
#
# 30	-	c
#
# 31	-	b
#
# 32	-	b
#
# 33	-	b
#
# 34	-	b
#
# 35	-	c
#
# 36	-	a
#
# 37	-	c
#
# 38	-	a
#
# 39	-	b
#
# 40	-	c
#
# 41	-	a
#
# 42	-	a
#
# 43	-	b
#
# 44	-	b
#
# 45	-	c
#
# 46	-	b
#
# 47	-	d
#
# 48	-	b
#
# 49	-	a
#
# 50	-	c
#
# 51	-	a
#
# 52	-	b
#
# 53	-	b
#
# 54	-
#
# 55	-	c
#
# 56	-	c
#
# 57	-	b,c,e
#
# 58	-	animals/feline/
#
# 59	-
#
# 60	-	animals/ursine/bears.gif
#
# 61	-	d
#
# 62	-
#
# 63	-	a
#
# 64	-	a
#
# 65	-	b
#
# 66	-	b
#
# 67	-	b
#
# 68	-	b
#
# 69	-	a
#
# 70	-	a
#
# 71	-	c
#
# 72	-	a
#
# 73	-	a
#
# 74	-	d
#
# 75	-	a
#
# 76	-	a
#
# 77	-	a
#
# 78	-	d
#
# 79	-	b
#
# 80	-	d
#
# 81	-	c
#
# 82	-	a
#
# 83	-	b
#
# 84	-	c
#
# 85	-	d
#
# 86	-	a
#
# 87	-	b
#
# 88	-	d
#
# 89	-	c
#
# 90	-	c
#
# 91	-	b
#
# 92	-	c
#
# 93	-	a
#
# 94	-	d
#
# 95	-	a
#
# 96	-	b
#
# 97	-	c
#
# 98	-	c
#
# 99	-	b
#
# 100	-	a
#
# 101	-	d
#
# 102	-	a
#
# 103	-	a
#
# 104	-	d
#
# 105	-	b
#
# 106	-	a
#
# 107	-	a
#
# 108	-	b
#
# 109	-	a
#
# 110	-	a
#
# 111	-	c
#
# 112	-	b
#
# 113	-	a
#
# 114	-	b
#
# 115	-	c
#
# 116	-	b
#
# 117	-	b
#
# 118	-	c
#
# 119	-	a
#
# 120	-	a
#
# 121	-	c
#
# 122	-	d
#
# 123	-	a
#
# 124	-	a
#
# 125	-	c
#
# 126	-	a
#
# 127	-	b
#
# 128	-	c
#
# 129	-	a
#
# 130	-	a
#
# 131	-	a
#
# 132	-	a
#
# 133	-	a
#
# 134	-	a
#
# 135	-	c
#
# 136	-	b
#
# 137	-	b
#
# 138	-	a
#
# 139	-	b
#
# 140	-	a
#
# 141	-	b
#
# 142	-	d
#
# 143	-	d
#
# 144	-	a
#
# 145	-	a
#
# 146	-	a
#
# 147	-	b
#
# 148	-	a
#
# 149	-	b
#
# 150	-	a
